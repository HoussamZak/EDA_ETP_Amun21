# %% [markdown]
# It is a no brainer that BTC's price action dictates the trend in the overall market, hence when considering bid/ask spreads, volumes and volatility we will rely on BTC's volume, bid/ask and volatility data along with the crypto prices we investigate.
#
# Volume, bid/ask and volatility's data is downloaded on https://data.bitcoinity.org/bitcoin/.
# We made sure to download daily data from 21 FEB 2017 to 20 FEB 2022.
#
# Bitcoin + Altcoins historical price data is download from https://www.cryptodatadownload.com/data/binance/
# We made sure to download daily data from 21 FEB 2017 to 20 FEB 2022.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dates from FEB 21 2017 to FEB 20 2022

# %% [markdown]
# BTC Bid Ask Dataset

# %%
btc_bid_ask_spread = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\bitcoinity BTC only Volume Volatility ETC\bitcoinity_data_BTC_BIDASKSPREAD_21FEB2017_20FEB2022.csv')

#Resaving to get rid of the header cryptocompare.com that blocks merging with another DF
btc_bid_ask_spread.to_csv('btc_bid_ask_sp.csv', header=True, index =  True)
btc_bid_ask_sp = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\btc_bid_ask_sp.csv')

#Dropping irrelevant exchanges to keep main ones, big players
btc_bid_ask_sp.drop(columns=['itbit','btce','okcoin','bitstamp','others','cex.io'],  inplace= True)
btc_bid_ask_sp.drop(columns=['Unnamed: 0', 'Time'], inplace=True)
btc_bid_ask_sp.rename(columns={"bitfinex":"bitfinex_B/A_Sp", "gemini":"gemini_B/A_Sp", "coinbase":"coinbase_B/A_Sp", "kraken":"kraken_B/A_Sp"}, inplace= True)
btc_bid_ask_sp.head()
# Out:
#    bitfinex_B/A_Sp  coinbase_B/A_Sp  gemini_B/A_Sp  kraken_B/A_Sp
# 0         0.023603         0.023972       0.034287       0.145045
# 1         0.024976         0.031878       0.033959       0.190306
# 2         0.028105         0.028947       0.027275       0.160828
# 3         0.034259         0.059614       0.061314       0.287392
# 4         0.029173         0.031632       0.081819       0.288130

# %% [markdown]
# BTC Volatility + MarketCap + DailyVolume + Hashrate

# %%
# result = pd.concat([df1, df4], axis=1, join="inner")

# %% [markdown]
# Liquidity being a crucial aspect of financial markets, it is best monitored by following VOLUME data along with BID ASK

# %%
#VOLATILITY Dataframe
btc_volatility_df = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\bitcoinity BTC only Volume Volatility ETC\bitcoinity_data_VOLATILITY_21FEB2017_20FEB2022.csv')
#Dropping irrelevant exchanges
btc_volatility_df.drop(columns=['Time','campbx', 'itbit','btce','cex.io', 'hitbtc','therocktrading', 'okcoin', 'bitstamp','bit-x','bitbay','exmo'], inplace = True)
#Renaming columns for more clarity 
btc_volatility_df.rename(columns={"bitfinex":"bitfinex_Vola", "cex.io":"cex.io_VOLA", "gemini":"gemini_VOLA", "coinbase":"coinbase_VOLA", "kraken":"kraken_VOLA"}, inplace= True)
btc_volatility_df


#MARKET_CAP Dataframe
btc_mc_df = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\bitcoinity BTC only Volume Volatility ETC\bitcoinity_data_BTC_MC_21FEB2017_20FEB2022.csv')
#Scaling / Normalizing the MKT CAP column data
btc_mc_df

#PRICE + VOLUME Dataframe 
btc_price_volume_df = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\bitcoinity BTC only Volume Volatility ETC\bitcoinity_data_PRICE+VOL_21FEB2017_20FEB2022.csv')
btc_price_volume_df

#TRADE VOLUME Dataframe
btc_trade_volume = pd.read_csv(r'C:\Users\Fluffy\Desktop\Projects Coding\EDA_ETP_Amun21\bitcoinity BTC only Volume Volatility ETC\bitcoinity_data_trade_volume_daily_21FEB2017_20FEB2022.csv')
btc_trade_volume.drop(columns=['Time','bit-x','bitflyer','okcoin','bitstamp','bithumb', 'others'], inplace = True)

#Renaming columns for more clarity 
btc_trade_volume.rename(columns={"bitfinex":"bitfinex_TradVol",  "gemini":"gemini_TradVol", "coinbase":"coinbase_TradVol", "kraken":"kraken_TradVol"}, inplace= True)

# #Adding DELTA for VOLUME Changes on each exchange  
btc_trade_volume['bitfinex_DELTA_TradeVolume'] = (btc_trade_volume['bitfinex_TradVol'] - btc_trade_volume['bitfinex_TradVol'].shift(-1))
btc_trade_volume['gemini_DELTA_TradeVolume'] = (btc_trade_volume['gemini_TradVol'] - btc_trade_volume['gemini_TradVol'].shift(-1))
btc_trade_volume['kraken_DELTA_TradeVolume'] = (btc_trade_volume['kraken_TradVol'] - btc_trade_volume['kraken_TradVol'].shift(-1))
btc_trade_volume['coinbase_DELTA_TradeVolume'] = (btc_trade_volume['coinbase_TradVol'] - btc_trade_volume['coinbase_TradVol'].shift(-1))

btc_trade_volume
# Out:
#       bitfinex_TradVol  coinbase_TradVol  gemini_TradVol  kraken_TradVol  \
# 0         23340.104197       8140.190522     3738.592754    13760.791090
# 1         14325.964649       6860.737172     4097.343366    10719.475532
# 2         26155.646950       8682.368457     4717.121271    14094.938785
# 3         48194.734288      14253.111435     8659.156653    22441.141346
# 4         16284.702084       6718.722488     2471.077299    10254.864999
# ...                ...               ...             ...             ...
# 1821       3271.185668      11379.968441      759.144479     3512.796168
# 1822       6750.376666      21768.443317     1599.361652     5961.729146
# 1823       4655.787108      18744.530759     1340.042313     4585.823724
# 1824       1464.254169       7003.811127      339.921970     1640.393669
# 1825       3526.825152      12608.165776      735.500735     4171.464295
#
#       bitfinex_DELTA_TradeVolume  gemini_DELTA_TradeVolume  \
# 0                    9014.139548               -358.750612
# 1                  -11829.682301               -619.777906
# 2                  -22039.087338              -3942.035382
# 3                   31910.032205               6188.079354
# 4                    5203.655667                 43.292397
# ...                          ...                       ...
# 1821                -3479.190998               -840.217173
# 1822                 2094.589558                259.319339
# 1823                 3191.532939               1000.120343
# 1824                -2062.570982               -395.578765
# 1825                         NaN                       NaN
#
#       kraken_DELTA_TradeVolume  coinbase_DELTA_TradeVolume
# 0                  3041.315558                 1279.453349
# 1                 -3375.463253                -1821.631284
# 2                 -8346.202561                -5570.742978
# 3                 12186.276346                 7534.388947
# 4                  2517.345670                 1858.435367
# ...                        ...                         ...
# 1821              -2448.932978               -10388.474876
# 1822               1375.905422                 3023.912558
# 1823               2945.430055                11740.719632
# 1824              -2531.070626                -5604.354648
# 1825                       NaN                         NaN
#
# [1826 rows x 8 columns]

# %% [markdown]
# In the cell below, we merge all dataframe, BTC Price & Volume + MC + Volatility + Trade Volume + Bid Ask Spread

# %%
# result = pd.concat([df1, df4], axis=1, join="inner")
A = pd.concat([btc_price_volume_df, btc_trade_volume] , axis = 1, join = "inner")
B = pd.concat([A, btc_volatility_df], axis = 1 , join = "inner")


btc_metrics = pd.concat([B, btc_bid_ask_sp], axis= 1, join = "inner")
btc_metrics.drop(columns=['Time'], inplace = True)

btc_metrics.tail()
# Out:
#              price        volume  bitfinex_TradVol  coinbase_TradVol  \
# 1821  44104.455805  7.381284e+08       3271.185668      11379.968441
# 1822  42777.506300  1.400839e+09       6750.376666      21768.443317
# 1823  40542.517535  1.113515e+09       4655.787108      18744.530759
# 1824  40228.975656  3.901324e+08       1464.254169       7003.811127
# 1825  38924.016908  7.516132e+08       3526.825152      12608.165776
#
#       gemini_TradVol  kraken_TradVol  bitfinex_DELTA_TradeVolume  \
# 1821      759.144479     3512.796168                -3479.190998
# 1822     1599.361652     5961.729146                 2094.589558
# 1823     1340.042313     4585.823724                 3191.532939
# 1824      339.921970     1640.393669                -2062.570982
# 1825      735.500735     4171.464295                         NaN
#
#       gemini_DELTA_TradeVolume  kraken_DELTA_TradeVolume  \
# 1821               -840.217173              -2448.932978
# 1822                259.319339               1375.905422
# 1823               1000.120343               2945.430055
# 1824               -395.578765              -2531.070626
# 1825                       NaN                       NaN
#
#       coinbase_DELTA_TradeVolume  bitfinex_Vola  coinbase_VOLA  gemini_VOLA  \
# 1821               -10388.474876      73.100968      70.257757    71.122768
# 1822                 3023.912558     107.103840     107.167009   106.436344
# 1823                11740.719632     103.088964     101.740897   103.060015
# 1824                -5604.354648      60.882817      59.242272    58.928462
# 1825                         NaN      81.175609      80.644789    82.480153
#
#       kraken_VOLA  bitfinex_B/A_Sp  coinbase_B/A_Sp  gemini_B/A_Sp  \
# 1821    71.159057         0.005011         0.001453       0.009919
# 1822   105.242998         0.005725         0.001930       0.012209
# 1823   104.954672         0.006719         0.002595       0.015235
# 1824    57.456096         0.005580              NaN       0.011158
# 1825    80.441120         0.008394         0.002497       0.013475
#
#       kraken_B/A_Sp
# 1821       0.001359
# 1822       0.004564
# 1823       0.003752
# 1824       0.001908
# 1825       0.003353

# %% [markdown]
# Exxploring Correlations between BTC & Volatility, Trading Volume , BidAsk Spread

# %%
#Setting diagonal correlation style
sns.set(style = "white")

import pandas as pd
from sklearn import preprocessing

#Scaling Normalizing before Correlation
x = btc_metrics.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
btc_metrics_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(btc_metrics_scaled)

#Computing the correlation
col_list =['price',	'volume','bitfinex_TradVol','coinbase_TradVol','gemini_TradVol','kraken_TradVol','bitfinex_DELTA_TradeVolume','gemini_DELTA_TradeVolume','kraken_DELTA_TradeVolume','coinbase_DELTA_TradeVolume','bitfinex_Vola','coinbase_VOLA','gemini_VOLA','kraken_VOLA','bitfinex_B/A_Sp','coinbase_B/A_Sp',	'gemini_B/A_Sp',	'kraken_B/A_Sp']
btc_metrics_corr = pd.DataFrame(btc_metrics_scaled, columns= col_list)
btc_metrics_corr_df = btc_metrics_corr.corr()
btc_metrics_corr_df
# Out:
#                                price    volume  bitfinex_TradVol  \
# price                       1.000000  0.627990         -0.273270
# volume                      0.627990  1.000000          0.273126
# bitfinex_TradVol           -0.273270  0.273126          1.000000
# coinbase_TradVol            0.136505  0.711978          0.558861
# gemini_TradVol             -0.259480  0.229358          0.795494
# kraken_TradVol             -0.243313  0.295549          0.630909
# bitfinex_DELTA_TradeVolume -0.004638  0.192428          0.343400
# gemini_DELTA_TradeVolume   -0.004096  0.178817          0.273118
# kraken_DELTA_TradeVolume   -0.004595  0.220440          0.264696
# coinbase_DELTA_TradeVolume -0.006243  0.265914          0.249262
# bitfinex_Vola               0.830996  0.912538          0.003200
# coinbase_VOLA               0.817262  0.919873          0.008823
# gemini_VOLA                 0.823042  0.916437          0.003944
# kraken_VOLA                 0.820613  0.914013         -0.000282
# bitfinex_B/A_Sp            -0.232251  0.065105          0.411862
# coinbase_B/A_Sp            -0.134279  0.018342          0.179691
# gemini_B/A_Sp              -0.101682  0.248944          0.260181
# kraken_B/A_Sp              -0.365611 -0.134630          0.415279
#
#                             coinbase_TradVol  gemini_TradVol  kraken_TradVol  \
# price                               0.136505       -0.259480       -0.243313
# volume                              0.711978        0.229358        0.295549
# bitfinex_TradVol                    0.558861        0.795494        0.630909
# coinbase_TradVol                    1.000000        0.566892        0.761210
# gemini_TradVol                      0.566892        1.000000        0.708584
# kraken_TradVol                      0.761210        0.708584        1.000000
# bitfinex_DELTA_TradeVolume          0.330647        0.285442        0.307452
# gemini_DELTA_TradeVolume            0.319204        0.384974        0.298600
# kraken_DELTA_TradeVolume            0.388382        0.275499        0.406658
# coinbase_DELTA_TradeVolume          0.427786        0.268893        0.347198
# bitfinex_Vola                       0.506316        0.014673        0.077736
# coinbase_VOLA                       0.527965        0.025166        0.098195
# gemini_VOLA                         0.518565        0.019059        0.089852
# kraken_VOLA                         0.514059        0.012760        0.093302
# bitfinex_B/A_Sp                     0.300180        0.623769        0.504969
# coinbase_B/A_Sp                     0.233783        0.267983        0.335884
# gemini_B/A_Sp                       0.513057        0.147684        0.432369
# kraken_B/A_Sp                       0.080885        0.460251        0.350179
#
#                             bitfinex_DELTA_TradeVolume  \
# price                                        -0.004638
# volume                                        0.192428
# bitfinex_TradVol                              0.343400
# coinbase_TradVol                              0.330647
# gemini_TradVol                                0.285442
# kraken_TradVol                                0.307452
# bitfinex_DELTA_TradeVolume                    1.000000
# gemini_DELTA_TradeVolume                      0.768010
# kraken_DELTA_TradeVolume                      0.763578
# coinbase_DELTA_TradeVolume                    0.749692
# bitfinex_Vola                                 0.112353
# coinbase_VOLA                                 0.122727
# gemini_VOLA                                   0.117954
# kraken_VOLA                                   0.114509
# bitfinex_B/A_Sp                               0.122566
# coinbase_B/A_Sp                               0.132714
# gemini_B/A_Sp                                 0.204924
# kraken_B/A_Sp                                 0.070330
#
#                             gemini_DELTA_TradeVolume  \
# price                                      -0.004096
# volume                                      0.178817
# bitfinex_TradVol                            0.273118
# coinbase_TradVol                            0.319204
# gemini_TradVol                              0.384974
# kraken_TradVol                              0.298600
# bitfinex_DELTA_TradeVolume                  0.768010
# gemini_DELTA_TradeVolume                    1.000000
# kraken_DELTA_TradeVolume                    0.724016
# coinbase_DELTA_TradeVolume                  0.721213
# bitfinex_Vola                               0.106067
# coinbase_VOLA                               0.118737
# gemini_VOLA                                 0.114182
# kraken_VOLA                                 0.108388
# bitfinex_B/A_Sp                             0.115217
# coinbase_B/A_Sp                             0.117502
# gemini_B/A_Sp                               0.154726
# kraken_B/A_Sp                               0.064374
#
#                             kraken_DELTA_TradeVolume  \
# price                                      -0.004595
# volume                                      0.220440
# bitfinex_TradVol                            0.264696
# coinbase_TradVol                            0.388382
# gemini_TradVol                              0.275499
# kraken_TradVol                              0.406658
# bitfinex_DELTA_TradeVolume                  0.763578
# gemini_DELTA_TradeVolume                    0.724016
# kraken_DELTA_TradeVolume                    1.000000
# coinbase_DELTA_TradeVolume                  0.881020
# bitfinex_Vola                               0.135736
# coinbase_VOLA                               0.147653
# gemini_VOLA                                 0.142479
# kraken_VOLA                                 0.141052
# bitfinex_B/A_Sp                             0.121940
# coinbase_B/A_Sp                             0.145900
# gemini_B/A_Sp                               0.225801
# kraken_B/A_Sp                               0.054705
#
#                             coinbase_DELTA_TradeVolume  bitfinex_Vola  \
# price                                        -0.006243       0.830996
# volume                                        0.265914       0.912538
# bitfinex_TradVol                              0.249262       0.003200
# coinbase_TradVol                              0.427786       0.506316
# gemini_TradVol                                0.268893       0.014673
# kraken_TradVol                                0.347198       0.077736
# bitfinex_DELTA_TradeVolume                    0.749692       0.112353
# gemini_DELTA_TradeVolume                      0.721213       0.106067
# kraken_DELTA_TradeVolume                      0.881020       0.135736
# coinbase_DELTA_TradeVolume                    1.000000       0.172076
# bitfinex_Vola                                 0.172076       1.000000
# coinbase_VOLA                                 0.188947       0.997200
# gemini_VOLA                                   0.181390       0.998274
# kraken_VOLA                                   0.177247       0.996723
# bitfinex_B/A_Sp                               0.126780      -0.013980
# coinbase_B/A_Sp                               0.137449      -0.013865
# gemini_B/A_Sp                                 0.247425       0.156476
# kraken_B/A_Sp                                 0.060213      -0.219898
#
#                             coinbase_VOLA  gemini_VOLA  kraken_VOLA  \
# price                            0.817262     0.823042     0.820613
# volume                           0.919873     0.916437     0.914013
# bitfinex_TradVol                 0.008823     0.003944    -0.000282
# coinbase_TradVol                 0.527965     0.518565     0.514059
# gemini_TradVol                   0.025166     0.019059     0.012760
# kraken_TradVol                   0.098195     0.089852     0.093302
# bitfinex_DELTA_TradeVolume       0.122727     0.117954     0.114509
# gemini_DELTA_TradeVolume         0.118737     0.114182     0.108388
# kraken_DELTA_TradeVolume         0.147653     0.142479     0.141052
# coinbase_DELTA_TradeVolume       0.188947     0.181390     0.177247
# bitfinex_Vola                    0.997200     0.998274     0.996723
# coinbase_VOLA                    1.000000     0.998686     0.996297
# gemini_VOLA                      0.998686     1.000000     0.997362
# kraken_VOLA                      0.996297     0.997362     1.000000
# bitfinex_B/A_Sp                 -0.010204    -0.014777    -0.016214
# coinbase_B/A_Sp                 -0.001730    -0.009898    -0.010840
# gemini_B/A_Sp                    0.167738     0.163015     0.163454
# kraken_B/A_Sp                   -0.217611    -0.220939    -0.219674
#
#                             bitfinex_B/A_Sp  coinbase_B/A_Sp  gemini_B/A_Sp  \
# price                             -0.232251        -0.134279      -0.101682
# volume                             0.065105         0.018342       0.248944
# bitfinex_TradVol                   0.411862         0.179691       0.260181
# coinbase_TradVol                   0.300180         0.233783       0.513057
# gemini_TradVol                     0.623769         0.267983       0.147684
# kraken_TradVol                     0.504969         0.335884       0.432369
# bitfinex_DELTA_TradeVolume         0.122566         0.132714       0.204924
# gemini_DELTA_TradeVolume           0.115217         0.117502       0.154726
# kraken_DELTA_TradeVolume           0.121940         0.145900       0.225801
# coinbase_DELTA_TradeVolume         0.126780         0.137449       0.247425
# bitfinex_Vola                     -0.013980        -0.013865       0.156476
# coinbase_VOLA                     -0.010204        -0.001730       0.167738
# gemini_VOLA                       -0.014777        -0.009898       0.163015
# kraken_VOLA                       -0.016214        -0.010840       0.163454
# bitfinex_B/A_Sp                    1.000000         0.413781       0.158741
# coinbase_B/A_Sp                    0.413781         1.000000       0.291546
# gemini_B/A_Sp                      0.158741         0.291546       1.000000
# kraken_B/A_Sp                      0.743231         0.363391       0.190337
#
#                             kraken_B/A_Sp
# price                           -0.365611
# volume                          -0.134630
# bitfinex_TradVol                 0.415279
# coinbase_TradVol                 0.080885
# gemini_TradVol                   0.460251
# kraken_TradVol                   0.350179
# bitfinex_DELTA_TradeVolume       0.070330
# gemini_DELTA_TradeVolume         0.064374
# kraken_DELTA_TradeVolume         0.054705
# coinbase_DELTA_TradeVolume       0.060213
# bitfinex_Vola                   -0.219898
# coinbase_VOLA                   -0.217611
# gemini_VOLA                     -0.220939
# kraken_VOLA                     -0.219674
# bitfinex_B/A_Sp                  0.743231
# coinbase_B/A_Sp                  0.363391
# gemini_B/A_Sp                    0.190337
# kraken_B/A_Sp                    1.000000

# %%
#Generate a mask for upper triangle of the matrix 
mask = np.triu(np.ones_like(btc_metrics_corr_df, dtype=np.bool))

f, ax = plt.subplots(figsize=(15,15))
#Generate a custom diverging colormap
cmap = "RdBu"

sns.heatmap(
    btc_metrics_corr_df,
    mask = mask,
    cmap = cmap,
    center = 0,
    square = True,
    linewidths = 0.5, 
    cbar_kws={"shrink": 0.5}
)

"""
https://www.pluralsight.com/guides/finding-relationships-data-with-python
https://www.kaggle.com/janiobachmann/time-series-i-an-introductory-start/report
"""
# Out:
# '\nhttps://www.pluralsight.com/guides/finding-relationships-data-with-python\nhttps://www.kaggle.com/janiobachmann/time-series-i-an-introductory-start/report\n'

# %% [markdown]
# As seen on file #4, the strongest correlations imply packaged ETPs, and the negative correlations are obvious ones between HODLX, HODLV & the SBTC short BTC ETP.
#
# This shows that the packaged ETPs 15, 10 & ETP 5 are very reactive to changes in BTC price action, therefore we should explore correlation between these packaged ETPs and the BTC metrics we have above.
#
# To do so, we collect price data for altcoins packaged in the ETP 15 Ficas Active Crypto to associate with BTC metrics for correlation exploration.

# %% [markdown]
# Correlations ETP 15 Ficas Active Crypto & BTC Market Metrics.

# %%
#Collecting BTC daily data from yahoo finance
import yfinance as yf

#List of altcoin pairs in the ETP
#For Polkadot, I wrote DOT-CAD because the USD pair gives no data.
fifteen_ficas_active_crypto = ['BTC-USD', 'ETH-USD', 'MATIC-USD', 'AVAX-USD', 'SOL-USD', 'NEO-USD', 'TRX-USD', 'XLM-USD', 'XTZ-USD', 'ADA-USD', 'EOS-USD', 'BNB-USD', 'LTC-USD', 'XRP-USD', 'DOT-CAD']
fifteen_ficas_active_crypto_temp = yf.download(fifteen_ficas_active_crypto, start = "2017-02-21", end = "2022-02-20", data_source = "yahoo")
fifteen_ficas_active_crypto_temp.drop(columns = ['Volume', 'Open', 'Close','Low', 'High'], inplace= True)

#Merging with btc_data
# btc_metrics_and_15 = pd.merge(btc_metrics, fifteen_ficas_active_crypto_temp, how = 'right', on =['Date', 'Date'])

fifteen_ficas_active_crypto_temp
# Out:
# [*********************100%***********************]  15 of 15 completed
#            Adj Close                                                  \
#              ADA-USD   AVAX-USD     BNB-USD       BTC-USD    DOT-CAD
# Date
# 2017-02-21       NaN        NaN         NaN   1115.300049        NaN
# 2017-02-22       NaN        NaN         NaN   1117.439941        NaN
# 2017-02-23       NaN        NaN         NaN   1166.719971        NaN
# 2017-02-24       NaN        NaN         NaN   1173.680054        NaN
# 2017-02-25       NaN        NaN         NaN   1143.839966        NaN
# ...              ...        ...         ...           ...        ...
# 2022-02-16  1.084981  95.346115  427.918121  43961.859375  25.140911
# 2022-02-17  1.019895  88.123772  402.450043  40538.011719  23.016081
# 2022-02-18  0.997113  83.836975  399.569183  40030.976562  22.764868
# 2022-02-19  0.997703  85.099319  400.043579  40122.156250  22.824261
# 2022-02-20  0.932902  77.336784  380.825928  38431.378906  21.597540
#
#                                                                     \
#              EOS-USD      ETH-USD     LTC-USD MATIC-USD    NEO-USD
# Date
# 2017-02-21       NaN          NaN    3.783280       NaN        NaN
# 2017-02-22       NaN          NaN    3.805220       NaN        NaN
# 2017-02-23       NaN          NaN    3.842950       NaN        NaN
# 2017-02-24       NaN          NaN    3.846720       NaN        NaN
# 2017-02-25       NaN          NaN    3.826110       NaN        NaN
# ...              ...          ...         ...       ...        ...
# 2022-02-16  2.553727  3127.830078  128.160843  1.838526  25.735397
# 2022-02-17  2.325260  2881.481934  116.302414  1.656870  23.636122
# 2022-02-18  2.299217  2785.727539  115.197090  1.595514  26.271097
# 2022-02-19  2.289203  2763.701172  115.709007  1.631835  25.046930
# 2022-02-20  2.206110  2628.648438  110.832039  1.515849  23.131954
#
#
#                SOL-USD   TRX-USD   XLM-USD   XRP-USD   XTZ-USD
# Date
# 2017-02-21         NaN       NaN       NaN       NaN       NaN
# 2017-02-22         NaN       NaN       NaN       NaN       NaN
# 2017-02-23         NaN       NaN       NaN       NaN       NaN
# 2017-02-24         NaN       NaN       NaN       NaN       NaN
# 2017-02-25         NaN       NaN       NaN       NaN       NaN
# ...                ...       ...       ...       ...       ...
# 2022-02-16  101.932899  0.066471  0.219271  0.839036  4.047968
# 2022-02-17   93.410423  0.062480  0.202432  0.767173  3.674452
# 2022-02-18   90.065460  0.063147  0.201102  0.785890  3.628554
# 2022-02-19   91.496651  0.063556  0.204239  0.822528  3.606206
# 2022-02-20   90.901413  0.062066  0.194932  0.778296  3.273977
#
# [1826 rows x 15 columns]

# %%
#Creating a Date column to add the btc_metrics DF
btc_metrics['Date'] = fifteen_ficas_active_crypto_temp.index
#Reordering to put new Date column in front
btc_metrics[['Date','price','volume','bitfinex_TradVol','coinbase_TradVol',	'gemini_TradVol','kraken_TradVol','bitfinex_DELTA_TradeVolume','gemini_DELTA_TradeVolume','kraken_DELTA_TradeVolume','coinbase_DELTA_TradeVolume','bitfinex_Vola','coinbase_VOLA','gemini_VOLA','kraken_VOLA','bitfinex_B/A_Sp','coinbase_B/A_Sp','gemini_B/A_Sp','kraken_B/A_Sp']]
btc_metrics_and_15 = pd.merge(btc_metrics, fifteen_ficas_active_crypto_temp, how = 'right', on =['Date', 'Date'])
# btc_metrics_and_15.drop(columns=['X'], inplace=True)
#Renaming some columns btc_metrics_and_15 for better readability
btc_metrics_and_15.columns = [                     'BTC_price',                     'BTC_volume',
                 'bitfinex_TradVol',           'coinbase_TradVol',
                   'gemini_TradVol',             'kraken_TradVol',
       'bitfinex_DELTA_TradeVolume',   'gemini_DELTA_TradeVolume',
         'kraken_DELTA_TradeVolume', 'coinbase_DELTA_TradeVolume',
                    'bitfinex_Vola',              'coinbase_VOLA',
                      'gemini_VOLA',                'kraken_VOLA',
                  'bitfinex_B/A_Sp',            'coinbase_B/A_Sp',
                    'gemini_B/A_Sp',              'kraken_B/A_Sp',
                                                    'Date',
           ('ADA-USD'),    ('AVAX-USD'),
           ('BNB-USD'),     ('BTC-USD'),
           ('DOT-CAD'),     ('EOS-USD'),
           ('ETH-USD'),     ('LTC-USD'),
         ('MATIC-USD'),     ('NEO-USD'),
           ('SOL-USD'),     ('TRX-USD'),
           ('XLM-USD'),     ('XRP-USD'),
           ('XTZ-USD')]
# btc_metrics_and_15 = pd.concat([fifteen_ficas_active_crypto_temp, btc_bid_ask_sp], axis= 1, join = "inner")
btc_metrics_and_15
# Out:
# C:\Users\Fluffy\AppData\Local\Temp/ipykernel_18100/4078675754.py:5: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   btc_metrics_and_15 = pd.merge(btc_metrics, fifteen_ficas_active_crypto_temp, how = 'right', on =['Date', 'Date'])
#          BTC_price    BTC_volume  bitfinex_TradVol  coinbase_TradVol  \
# 0      1099.745646  7.286941e+07      23340.104197       8140.190522
# 1      1118.812147  6.158405e+07      14325.964649       6860.737172
# 2      1143.364369  8.678880e+07      26155.646950       8682.368457
# 3      1178.822928  1.443649e+08      48194.734288      14253.111435
# 4      1164.845901  5.372576e+07      16284.702084       6718.722488
# ...            ...           ...               ...               ...
# 1821  44104.455805  7.381284e+08       3271.185668      11379.968441
# 1822  42777.506300  1.400839e+09       6750.376666      21768.443317
# 1823  40542.517535  1.113515e+09       4655.787108      18744.530759
# 1824  40228.975656  3.901324e+08       1464.254169       7003.811127
# 1825  38924.016908  7.516132e+08       3526.825152      12608.165776
#
#       gemini_TradVol  kraken_TradVol  bitfinex_DELTA_TradeVolume  \
# 0        3738.592754    13760.791090                 9014.139548
# 1        4097.343366    10719.475532               -11829.682301
# 2        4717.121271    14094.938785               -22039.087338
# 3        8659.156653    22441.141346                31910.032205
# 4        2471.077299    10254.864999                 5203.655667
# ...              ...             ...                         ...
# 1821      759.144479     3512.796168                -3479.190998
# 1822     1599.361652     5961.729146                 2094.589558
# 1823     1340.042313     4585.823724                 3191.532939
# 1824      339.921970     1640.393669                -2062.570982
# 1825      735.500735     4171.464295                         NaN
#
#       gemini_DELTA_TradeVolume  kraken_DELTA_TradeVolume  \
# 0                  -358.750612               3041.315558
# 1                  -619.777906              -3375.463253
# 2                 -3942.035382              -8346.202561
# 3                  6188.079354              12186.276346
# 4                    43.292397               2517.345670
# ...                        ...                       ...
# 1821               -840.217173              -2448.932978
# 1822                259.319339               1375.905422
# 1823               1000.120343               2945.430055
# 1824               -395.578765              -2531.070626
# 1825                       NaN                       NaN
#
#       coinbase_DELTA_TradeVolume  ...   EOS-USD      ETH-USD     LTC-USD  \
# 0                    1279.453349  ...       NaN          NaN    3.783280
# 1                   -1821.631284  ...       NaN          NaN    3.805220
# 2                   -5570.742978  ...       NaN          NaN    3.842950
# 3                    7534.388947  ...       NaN          NaN    3.846720
# 4                    1858.435367  ...       NaN          NaN    3.826110
# ...                          ...  ...       ...          ...         ...
# 1821               -10388.474876  ...  2.553727  3127.830078  128.160843
# 1822                 3023.912558  ...  2.325260  2881.481934  116.302414
# 1823                11740.719632  ...  2.299217  2785.727539  115.197090
# 1824                -5604.354648  ...  2.289203  2763.701172  115.709007
# 1825                         NaN  ...  2.206110  2628.648438  110.832039
#
#       MATIC-USD    NEO-USD     SOL-USD   TRX-USD   XLM-USD   XRP-USD   XTZ-USD
# 0           NaN        NaN         NaN       NaN       NaN       NaN       NaN
# 1           NaN        NaN         NaN       NaN       NaN       NaN       NaN
# 2           NaN        NaN         NaN       NaN       NaN       NaN       NaN
# 3           NaN        NaN         NaN       NaN       NaN       NaN       NaN
# 4           NaN        NaN         NaN       NaN       NaN       NaN       NaN
# ...         ...        ...         ...       ...       ...       ...       ...
# 1821   1.838526  25.735397  101.932899  0.066471  0.219271  0.839036  4.047968
# 1822   1.656870  23.636122   93.410423  0.062480  0.202432  0.767173  3.674452
# 1823   1.595514  26.271097   90.065460  0.063147  0.201102  0.785890  3.628554
# 1824   1.631835  25.046930   91.496651  0.063556  0.204239  0.822528  3.606206
# 1825   1.515849  23.131954   90.901413  0.062066  0.194932  0.778296  3.273977
#
# [1826 rows x 34 columns]

# %%
col_list = btc_metrics_and_15.columns
btc_metrics_and_15_corr = pd.DataFrame(btc_metrics_and_15, columns= col_list)
btc_metrics_and_15_corr_df = btc_metrics_and_15_corr.corr()
btc_metrics_and_15_corr_df
# Out:
#                             BTC_price  BTC_volume  bitfinex_TradVol  \
# BTC_price                    1.000000    0.627990         -0.273270
# BTC_volume                   0.627990    1.000000          0.273126
# bitfinex_TradVol            -0.273270    0.273126          1.000000
# coinbase_TradVol             0.136505    0.711978          0.558861
# gemini_TradVol              -0.259480    0.229358          0.795494
# kraken_TradVol              -0.243313    0.295549          0.630909
# bitfinex_DELTA_TradeVolume  -0.004638    0.192428          0.343400
# gemini_DELTA_TradeVolume    -0.004096    0.178817          0.273118
# kraken_DELTA_TradeVolume    -0.004595    0.220440          0.264696
# coinbase_DELTA_TradeVolume  -0.006243    0.265914          0.249262
# bitfinex_Vola                0.830996    0.912538          0.003200
# coinbase_VOLA                0.817262    0.919873          0.008823
# gemini_VOLA                  0.823042    0.916437          0.003944
# kraken_VOLA                  0.820613    0.914013         -0.000282
# bitfinex_B/A_Sp             -0.232251    0.065105          0.411862
# coinbase_B/A_Sp             -0.134279    0.018342          0.179691
# gemini_B/A_Sp               -0.101682    0.248944          0.260181
# kraken_B/A_Sp               -0.365611   -0.134630          0.415279
# ADA-USD                      0.890947    0.472799         -0.167001
# AVAX-USD                     0.621020   -0.015124         -0.248079
# BNB-USD                      0.920312    0.439577         -0.261598
# BTC-USD                      0.999492    0.627690         -0.273185
# DOT-CAD                      0.950191    0.330525         -0.034976
# EOS-USD                     -0.034703    0.113979          0.328502
# ETH-USD                      0.924513    0.494164         -0.175225
# LTC-USD                      0.756867    0.668681          0.063830
# MATIC-USD                    0.750511    0.337246         -0.125370
# NEO-USD                      0.337237    0.418808          0.401558
# SOL-USD                      0.671320    0.126434         -0.162432
# TRX-USD                      0.779358    0.448707         -0.079361
# XLM-USD                      0.642544    0.552763          0.156723
# XRP-USD                      0.562599    0.416658          0.158627
# XTZ-USD                      0.740447    0.477462         -0.001637
#
#                             coinbase_TradVol  gemini_TradVol  kraken_TradVol  \
# BTC_price                           0.136505       -0.259480       -0.243313
# BTC_volume                          0.711978        0.229358        0.295549
# bitfinex_TradVol                    0.558861        0.795494        0.630909
# coinbase_TradVol                    1.000000        0.566892        0.761210
# gemini_TradVol                      0.566892        1.000000        0.708584
# kraken_TradVol                      0.761210        0.708584        1.000000
# bitfinex_DELTA_TradeVolume          0.330647        0.285442        0.307452
# gemini_DELTA_TradeVolume            0.319204        0.384974        0.298600
# kraken_DELTA_TradeVolume            0.388382        0.275499        0.406658
# coinbase_DELTA_TradeVolume          0.427786        0.268893        0.347198
# bitfinex_Vola                       0.506316        0.014673        0.077736
# coinbase_VOLA                       0.527965        0.025166        0.098195
# gemini_VOLA                         0.518565        0.019059        0.089852
# kraken_VOLA                         0.514059        0.012760        0.093302
# bitfinex_B/A_Sp                     0.300180        0.623769        0.504969
# coinbase_B/A_Sp                     0.233783        0.267983        0.335884
# gemini_B/A_Sp                       0.513057        0.147684        0.432369
# kraken_B/A_Sp                       0.080885        0.460251        0.350179
# ADA-USD                             0.048811       -0.109703       -0.218926
# AVAX-USD                           -0.190863       -0.275216       -0.420743
# BNB-USD                             0.019608       -0.202924       -0.252986
# BTC-USD                             0.136486       -0.259630       -0.244037
# DOT-CAD                            -0.055079       -0.110304       -0.237880
# EOS-USD                            -0.021910        0.217976        0.026020
# ETH-USD                             0.064167       -0.125101       -0.223470
# LTC-USD                             0.230221       -0.046701       -0.113379
# MATIC-USD                          -0.015358       -0.083447       -0.306132
# NEO-USD                             0.156862        0.338794        0.112261
# SOL-USD                            -0.143140       -0.209116       -0.398198
# TRX-USD                             0.009883       -0.052976       -0.194083
# XLM-USD                             0.112078        0.141050       -0.033303
# XRP-USD                             0.072425        0.164074       -0.091175
# XTZ-USD                             0.079174        0.014329       -0.159991
#
#                             bitfinex_DELTA_TradeVolume  \
# BTC_price                                    -0.004638
# BTC_volume                                    0.192428
# bitfinex_TradVol                              0.343400
# coinbase_TradVol                              0.330647
# gemini_TradVol                                0.285442
# kraken_TradVol                                0.307452
# bitfinex_DELTA_TradeVolume                    1.000000
# gemini_DELTA_TradeVolume                      0.768010
# kraken_DELTA_TradeVolume                      0.763578
# coinbase_DELTA_TradeVolume                    0.749692
# bitfinex_Vola                                 0.112353
# coinbase_VOLA                                 0.122727
# gemini_VOLA                                   0.117954
# kraken_VOLA                                   0.114509
# bitfinex_B/A_Sp                               0.122566
# coinbase_B/A_Sp                               0.132714
# gemini_B/A_Sp                                 0.204924
# kraken_B/A_Sp                                 0.070330
# ADA-USD                                      -0.007786
# AVAX-USD                                     -0.016866
# BNB-USD                                      -0.007123
# BTC-USD                                      -0.003652
# DOT-CAD                                      -0.036627
# EOS-USD                                      -0.025735
# ETH-USD                                      -0.008856
# LTC-USD                                      -0.016510
# MATIC-USD                                    -0.012046
# NEO-USD                                      -0.022326
# SOL-USD                                      -0.010012
# TRX-USD                                      -0.013230
# XLM-USD                                      -0.021138
# XRP-USD                                      -0.017569
# XTZ-USD                                      -0.021682
#
#                             gemini_DELTA_TradeVolume  \
# BTC_price                                  -0.004096
# BTC_volume                                  0.178817
# bitfinex_TradVol                            0.273118
# coinbase_TradVol                            0.319204
# gemini_TradVol                              0.384974
# kraken_TradVol                              0.298600
# bitfinex_DELTA_TradeVolume                  0.768010
# gemini_DELTA_TradeVolume                    1.000000
# kraken_DELTA_TradeVolume                    0.724016
# coinbase_DELTA_TradeVolume                  0.721213
# bitfinex_Vola                               0.106067
# coinbase_VOLA                               0.118737
# gemini_VOLA                                 0.114182
# kraken_VOLA                                 0.108388
# bitfinex_B/A_Sp                             0.115217
# coinbase_B/A_Sp                             0.117502
# gemini_B/A_Sp                               0.154726
# kraken_B/A_Sp                               0.064374
# ADA-USD                                    -0.008961
# AVAX-USD                                   -0.016718
# BNB-USD                                    -0.008090
# BTC-USD                                    -0.002855
# DOT-CAD                                    -0.037263
# EOS-USD                                    -0.029801
# ETH-USD                                    -0.009816
# LTC-USD                                    -0.017579
# MATIC-USD                                  -0.011470
# NEO-USD                                    -0.025190
# SOL-USD                                    -0.007872
# TRX-USD                                    -0.011657
# XLM-USD                                    -0.023731
# XRP-USD                                    -0.018742
# XTZ-USD                                    -0.031618
#
#                             kraken_DELTA_TradeVolume  \
# BTC_price                                  -0.004595
# BTC_volume                                  0.220440
# bitfinex_TradVol                            0.264696
# coinbase_TradVol                            0.388382
# gemini_TradVol                              0.275499
# kraken_TradVol                              0.406658
# bitfinex_DELTA_TradeVolume                  0.763578
# gemini_DELTA_TradeVolume                    0.724016
# kraken_DELTA_TradeVolume                    1.000000
# coinbase_DELTA_TradeVolume                  0.881020
# bitfinex_Vola                               0.135736
# coinbase_VOLA                               0.147653
# gemini_VOLA                                 0.142479
# kraken_VOLA                                 0.141052
# bitfinex_B/A_Sp                             0.121940
# coinbase_B/A_Sp                             0.145900
# gemini_B/A_Sp                               0.225801
# kraken_B/A_Sp                               0.054705
# ADA-USD                                    -0.008200
# AVAX-USD                                   -0.014081
# BNB-USD                                    -0.008733
# BTC-USD                                    -0.003522
# DOT-CAD                                    -0.029893
# EOS-USD                                    -0.029093
# ETH-USD                                    -0.009387
# LTC-USD                                    -0.019697
# MATIC-USD                                  -0.007922
# NEO-USD                                    -0.023248
# SOL-USD                                    -0.007629
# TRX-USD                                    -0.017245
# XLM-USD                                    -0.025098
# XRP-USD                                    -0.021371
# XTZ-USD                                    -0.026697
#
#                             coinbase_DELTA_TradeVolume  ...   EOS-USD  \
# BTC_price                                    -0.006243  ... -0.034703
# BTC_volume                                    0.265914  ...  0.113979
# bitfinex_TradVol                              0.249262  ...  0.328502
# coinbase_TradVol                              0.427786  ... -0.021910
# gemini_TradVol                                0.268893  ...  0.217976
# kraken_TradVol                                0.347198  ...  0.026020
# bitfinex_DELTA_TradeVolume                    0.749692  ... -0.025735
# gemini_DELTA_TradeVolume                      0.721213  ... -0.029801
# kraken_DELTA_TradeVolume                      0.881020  ... -0.029093
# coinbase_DELTA_TradeVolume                    1.000000  ... -0.027778
# bitfinex_Vola                                 0.172076  ...  0.028548
# coinbase_VOLA                                 0.188947  ...  0.019847
# gemini_VOLA                                   0.181390  ...  0.022881
# kraken_VOLA                                   0.177247  ...  0.027570
# bitfinex_B/A_Sp                               0.126780  ...  0.026426
# coinbase_B/A_Sp                               0.137449  ... -0.055896
# gemini_B/A_Sp                                 0.247425  ...  0.007734
# kraken_B/A_Sp                                 0.060213  ...  0.390896
# ADA-USD                                      -0.009129  ...  0.101817
# AVAX-USD                                     -0.016021  ...  0.038930
# BNB-USD                                      -0.011513  ... -0.021723
# BTC-USD                                      -0.004607  ... -0.035074
# DOT-CAD                                      -0.033868  ...  0.614317
# EOS-USD                                      -0.027778  ...  1.000000
# ETH-USD                                      -0.011218  ...  0.061677
# LTC-USD                                      -0.021043  ...  0.494765
# MATIC-USD                                    -0.010800  ...  0.219242
# NEO-USD                                      -0.022827  ...  0.706157
# SOL-USD                                      -0.010000  ...  0.215432
# TRX-USD                                      -0.016913  ...  0.436369
# XLM-USD                                      -0.022270  ...  0.599901
# XRP-USD                                      -0.019670  ...  0.533900
# XTZ-USD                                      -0.028913  ...  0.373049
#
#                              ETH-USD   LTC-USD  MATIC-USD   NEO-USD   SOL-USD  \
# BTC_price                   0.924513  0.756867   0.750511  0.337237  0.671320
# BTC_volume                  0.494164  0.668681   0.337246  0.418808  0.126434
# bitfinex_TradVol           -0.175225  0.063830  -0.125370  0.401558 -0.162432
# coinbase_TradVol            0.064167  0.230221  -0.015358  0.156862 -0.143140
# gemini_TradVol             -0.125101 -0.046701  -0.083447  0.338794 -0.209116
# kraken_TradVol             -0.223470 -0.113379  -0.306132  0.112261 -0.398198
# bitfinex_DELTA_TradeVolume -0.008856 -0.016510  -0.012046 -0.022326 -0.010012
# gemini_DELTA_TradeVolume   -0.009816 -0.017579  -0.011470 -0.025190 -0.007872
# kraken_DELTA_TradeVolume   -0.009387 -0.019697  -0.007922 -0.023248 -0.007629
# coinbase_DELTA_TradeVolume -0.011218 -0.021043  -0.010800 -0.022827 -0.010000
# bitfinex_Vola               0.716848  0.728461   0.531854  0.382391  0.318497
# coinbase_VOLA               0.703687  0.709826   0.521874  0.367835  0.306084
# gemini_VOLA                 0.709005  0.717020   0.524881  0.373792  0.311544
# kraken_VOLA                 0.703950  0.717596   0.515756  0.377009  0.301628
# bitfinex_B/A_Sp            -0.039396 -0.167946  -0.167028  0.290882 -0.347818
# coinbase_B/A_Sp            -0.065903 -0.148582  -0.208566 -0.081780 -0.216238
# gemini_B/A_Sp              -0.243360 -0.009504  -0.329763 -0.028860 -0.439315
# kraken_B/A_Sp              -0.276259 -0.264544  -0.384541  0.394739 -0.238218
# ADA-USD                     0.938689  0.702553   0.835134  0.437503  0.733169
# AVAX-USD                    0.813321  0.343343   0.785298  0.091592  0.892434
# BNB-USD                     0.961627  0.646707   0.893086  0.310705  0.798989
# BTC-USD                     0.922734  0.756957   0.747363  0.336562  0.666944
# DOT-CAD                     0.810689  0.859531   0.539426  0.671506  0.642666
# EOS-USD                     0.061677  0.494765   0.219242  0.706157  0.215432
# ETH-USD                     1.000000  0.704443   0.919980  0.403696  0.875584
# LTC-USD                     0.704443  1.000000   0.606195  0.770926  0.482368
# MATIC-USD                   0.919980  0.606195   1.000000  0.541476  0.843265
# NEO-USD                     0.403696  0.770926   0.541476  1.000000  0.301277
# SOL-USD                     0.875584  0.482368   0.843265  0.301277  1.000000
# TRX-USD                     0.828254  0.813974   0.762074  0.647283  0.674488
# XLM-USD                     0.639203  0.844191   0.601006  0.815644  0.374242
# XRP-USD                     0.656836  0.811938   0.769175  0.781102  0.653420
# XTZ-USD                     0.757031  0.785044   0.661808  0.632763  0.698433
#
#                              TRX-USD   XLM-USD   XRP-USD   XTZ-USD
# BTC_price                   0.779358  0.642544  0.562599  0.740447
# BTC_volume                  0.448707  0.552763  0.416658  0.477462
# bitfinex_TradVol           -0.079361  0.156723  0.158627 -0.001637
# coinbase_TradVol            0.009883  0.112078  0.072425  0.079174
# gemini_TradVol             -0.052976  0.141050  0.164074  0.014329
# kraken_TradVol             -0.194083 -0.033303 -0.091175 -0.159991
# bitfinex_DELTA_TradeVolume -0.013230 -0.021138 -0.017569 -0.021682
# gemini_DELTA_TradeVolume   -0.011657 -0.023731 -0.018742 -0.031618
# kraken_DELTA_TradeVolume   -0.017245 -0.025098 -0.021371 -0.026697
# coinbase_DELTA_TradeVolume -0.016913 -0.022270 -0.019670 -0.028913
# bitfinex_Vola               0.610123  0.621741  0.492459  0.589568
# coinbase_VOLA               0.595951  0.603738  0.475306  0.573040
# gemini_VOLA                 0.603031  0.610913  0.483137  0.580366
# kraken_VOLA                 0.601523  0.615260  0.484878  0.578216
# bitfinex_B/A_Sp            -0.054262  0.111345  0.142402  0.071142
# coinbase_B/A_Sp            -0.086003 -0.078557 -0.076280 -0.091701
# gemini_B/A_Sp              -0.230880 -0.065947 -0.128941 -0.182619
# kraken_B/A_Sp              -0.135031  0.088688  0.192183 -0.044905
# ADA-USD                     0.836355  0.667624  0.694084  0.754595
# AVAX-USD                    0.537295  0.228289  0.482414  0.602598
# BNB-USD                     0.809495  0.572595  0.593920  0.684624
# BTC-USD                     0.778106  0.642607  0.561740  0.740361
# DOT-CAD                     0.848044  0.824381  0.757242  0.874617
# EOS-USD                     0.436369  0.599901  0.533900  0.373049
# ETH-USD                     0.828254  0.639203  0.656836  0.757031
# LTC-USD                     0.813974  0.844191  0.811938  0.785044
# MATIC-USD                   0.762074  0.601006  0.769175  0.661808
# NEO-USD                     0.647283  0.815644  0.781102  0.632763
# SOL-USD                     0.674488  0.374242  0.653420  0.698433
# TRX-USD                     1.000000  0.831608  0.868681  0.807190
# XLM-USD                     0.831608  1.000000  0.846390  0.716158
# XRP-USD                     0.868681  0.846390  1.000000  0.712598
# XTZ-USD                     0.807190  0.716158  0.712598  1.000000
#
# [33 rows x 33 columns]

# %%
dfCorr = btc_metrics_and_15_corr_df.corr()
filteredDf = dfCorr[((dfCorr >= .8) | (dfCorr <= -.8)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,10))
sns.heatmap(filteredDf, annot=True, cmap="RdBu")
plt.show()
